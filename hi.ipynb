# %% [markdown]
# <a href="https://colab.research.google.com/github/Average-Me/weather-temperature-forecast-finland/blob/main/hi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Hi')
# Out:
# Hi
